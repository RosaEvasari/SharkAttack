# %%
import pandas as pd
import os

url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"

data = pd.read_excel(url)

# %%
data.head()
# Out:
#           Date    Year        Type    Country              State  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1  04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2  02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3  25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4  14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
#
#                            Location  Activity                 Name Sex  Age  \
# 0                     Bargara Beach  Swimming       Brooklyn Sauer   F   13
# 1                Old Man's, Waikiki   Surfing        Matthew White   M  NaN
# 2                    Rainbows, Oahu  Swimming                  NaN   F   11
# 3        Sandlnd Island, Jurian Bay       NaN               female   F   46
# 4  Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari   M   32
#
#    ...        Species                      Source  pdf href formula href  \
# ...

# %%
data.shape
# Out:
# (6969, 23)

# %%
data.describe()
# Out:
#               Year  original order
# count  6942.000000     6799.000000
# mean   1934.403342     3401.152081
# std     272.920956     1963.076319
# min       0.000000        2.000000
# 25%    1947.000000     1701.500000
# 50%    1985.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2024.000000     6802.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6969 entries, 0 to 6968
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6944 non-null   object
#  1   Year            6942 non-null   float64
#  2   Type            6926 non-null   object
#  3   Country         6894 non-null   object
#  4   State           6462 non-null   object
#  5   Location        6379 non-null   object
#  6   Activity        6358 non-null   object
#  7   Name            6724 non-null   object
#  8   Sex             6365 non-null   object
#  9   Age             3950 non-null   object
#  10  Injury          6909 non-null   object
#  11  Unnamed: 11     6382 non-null   object
#  12  Time            3418 non-null   object
#  13  Species         3812 non-null   object
#  14  Source          6925 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6819 non-null   object
# ...

# %%
data.nunique()
# Out:
# Date              6003
# Year               259
# Type                12
# Country            225
# State              902
# Location          4514
# Activity          1587
# Name              5683
# Sex                  8
# Age                243
# Injury            4079
# Unnamed: 11         12
# Time               410
# Species           1675
# Source            5302
# pdf               6789
# href formula      6785
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
data.Sex.unique()
# Out:
# array(['F', 'M', nan, ' M', 'M ', 'lli', 'M x 2', 'N', '.'], dtype=object)

# %%
data.Country.unique()
# Out:
# array(['AUSTRALIA', 'USA', 'INDIA', 'TRINIDAD', 'BAHAMAS', 'SOUTH AFRICA',
#        'MEXICO', 'NEW ZEALAND', 'EGYPT', 'Mexico', 'BELIZE',
#        'PHILIPPINES', 'Coral Sea', 'SPAIN', 'PORTUGAL', 'SAMOA',
#        'COLOMBIA', 'ECUADOR', 'FRENCH POLYNESIA', 'NEW CALEDONIA',
#        'TURKS and CaICOS', 'CUBA', 'BRAZIL', 'SEYCHELLES', 'ARGENTINA',
#        'FIJI', 'MeXICO', 'Maldives', 'South Africa', 'ENGLAND', 'JAPAN',
#        'INDONESIA', 'JAMAICA', 'MALDIVES', 'THAILAND', 'COLUMBIA',
#        'COSTA RICA', 'New Zealand', 'British Overseas Territory',
#        'CANADA', 'JORDAN', 'ST KITTS / NEVIS', 'ST MARTIN',
#        'PAPUA NEW GUINEA', 'REUNION ISLAND', 'ISRAEL', 'CHINA', 'IRELAND',
#        'ITALY', 'MALAYSIA', 'LIBYA', nan, 'MAURITIUS', 'SOLOMON ISLANDS',
#        'ST HELENA, British overseas territory', 'COMOROS', 'REUNION',
#        'UNITED KINGDOM', 'UNITED ARAB EMIRATES', 'CAPE VERDE', 'Fiji',
#        'DOMINICAN REPUBLIC', 'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6969 entries, 0 to 6968
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6944 non-null   object
#  1   Year            6942 non-null   float64
#  2   Type            6926 non-null   object
#  3   Country         6894 non-null   object
#  4   State           6462 non-null   object
#  5   Location        6379 non-null   object
#  6   Activity        6358 non-null   object
#  7   Name            6724 non-null   object
#  8   Sex             6365 non-null   object
#  9   Age             3950 non-null   object
#  10  Injury          6909 non-null   object
#  11  Unnamed: 11     6382 non-null   object
#  12  Time            3418 non-null   object
#  13  Species         3812 non-null   object
#  14  Source          6925 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6819 non-null   object
# ...

# %%
selected_columns = data[["Year", "Country", "Injury", "Location"]]
selected_columns
# Out:
#         Year    Country                                    Injury  \
# 0     2024.0  AUSTRALIA  Minor injuries to back, abdomen and legs
# 1     2024.0        USA            No injury, shark bit surfboard
# 2     2024.0        USA                  Lacerations to left foot
# 3     2024.0  AUSTRALIA                                Leg bitten
# 4     2024.0      INDIA            Calf of lower left leg injured
# ...      ...        ...                                       ...
# 6964     NaN        NaN                                       NaN
# 6965     NaN        NaN                                       NaN
# 6966     NaN        NaN                                       NaN
# 6967     NaN        NaN                                       NaN
# 6968     NaN        NaN                                       NaN
#
#                               Location
# 0                        Bargara Beach
# 1                   Old Man's, Waikiki
# 2                       Rainbows, Oahu
# ...

# %%
selected_columns = data[["Year", "Country", "Injury", "Location"]]
selected_columns

selected_collumns_clean =selected_columns.dropna()
selected_collumns_clean
# Out:
#         Year             Country  \
# 0     2024.0           AUSTRALIA
# 1     2024.0                 USA
# 2     2024.0                 USA
# 3     2024.0           AUSTRALIA
# 4     2024.0               INDIA
# ...      ...                 ...
# 6938     0.0           AUSTRALIA
# 6939     0.0           AUSTRALIA
# 6941     0.0                 USA
# 6942     0.0              PANAMA
# 6943     0.0  CEYLON (SRI LANKA)
#
#                                                  Injury  \
# 0              Minor injuries to back, abdomen and legs
# 1                        No injury, shark bit surfboard
# 2                              Lacerations to left foot
# 3                                            Leg bitten
# 4                        Calf of lower left leg injured
# ...                                                 ...
# 6938                                              FATAL
# 6939                                              FATAL
# ...

# %%
USA_data = selected_collumns_clean.loc[data['Country'] == 'USA']
USA_data
# Out:
#         Year Country                            Injury  \
# 1     2024.0     USA    No injury, shark bit surfboard
# 2     2024.0     USA          Lacerations to left foot
# 10    2023.0     USA                             FATAL
# 24    2023.0     USA      Lacerations to right forearm
# 29    2023.0     USA               Bite to right thigh
# ...      ...     ...                               ...
# 6891     0.0     USA  Abrasions & bruises hip to ankle
# 6925     0.0     USA                2-inch lacerations
# 6930     0.0     USA                        "Lost leg"
# 6934     0.0     USA                      Ankle bitten
# 6941     0.0     USA                             FATAL
#
#                                      Location
# 1                          Old Man's, Waikiki
# 2                              Rainbows, Oahu
# 10                           Baby Beach, Maui
# 24              Juno Beach, Palm Beach County
# 29              Pua’ena Point,  Haleiwa, Oahu
# ...

# %%
unique_locations = USA_data['Location'].unique()
print(f"Number of unique Locations: {unique_locations}")
# Out:
# Number of unique Locations: ["Old Man's, Waikiki" 'Rainbows, Oahu' 'Baby Beach, Maui' ...
#  'Capistrano, Orange County' 'Somewhere between Hatteras and Beaufort'
#  'Ocracoke Inlet']

# %%
location_counts = USA_data['Location'].value_counts()
location_counts
locations_counts_sum = sum(location_counts)

# %%
specific_beach_data = USA_data[USA_data['Location'] == 'New Smyrna Beach, Volusia County']
specific_beach_data
# Out:
#         Year Country                                      Injury  \
# 40    2023.0     USA               Llacerations to face and chin
# 54    2023.0     USA                               Ankle injured
# 159   2022.0     USA                        Minor injury to foot
# 162   2022.0     USA                                 Foot bitten
# 197   2022.0     USA                          Bite to right foot
# ...      ...     ...                                         ...
# 3889  1974.0     USA                  Lacerations to hip and leg
# 3946  1972.0     USA                                    Survived
# 4050  1969.0     USA                    Lacerations to lower leg
# 4371  1963.0     USA  Left forearm bitten, surgically amputated?
# 4440  1962.0     USA                  8" laceration on left calf
#
#                               Location
# 40    New Smyrna Beach, Volusia County
# 54    New Smyrna Beach, Volusia County
# 159   New Smyrna Beach, Volusia County
# ...

# %%
specific_beach_data['Year'] = specific_beach_data['Year'].astype(int)
specific_beach_data
# Out:
# C:\Users\Ironhack\AppData\Local\Temp\ipykernel_9320\1941169790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_beach_data['Year'] = specific_beach_data['Year'].astype(int)
#       Year Country                                      Injury  \
# 40    2023     USA               Llacerations to face and chin
# 54    2023     USA                               Ankle injured
# 159   2022     USA                        Minor injury to foot
# 162   2022     USA                                 Foot bitten
# 197   2022     USA                          Bite to right foot
# ...    ...     ...                                         ...
# 3889  1974     USA                  Lacerations to hip and leg
# ...

# %%
current_year = 2024

# Calculate the earliest year to include
earliest_year = current_year - 5

# Filter the DataFrame for the last 5 years
recent_injuries = specific_beach_data[specific_beach_data['Year'] >= earliest_year]

print(recent_injuries)
# Out:
#      Year Country                                             Injury  \
# 40   2023     USA                      Llacerations to face and chin
# 54   2023     USA                                      Ankle injured
# 159  2022     USA                               Minor injury to foot
# 162  2022     USA                                        Foot bitten
# 197  2022     USA                                 Bite to right foot
# 198  2022     USA  Minor injuries to knee and calf of left leg   ...
# 242  2021     USA                 Minor cuts to right foot and ankle
# 256  2021     USA                                         Leg bitten
# 274  2021     USA                                  Right calf bitten
# 275  2021     USA                         Minor injury to right foot
# 287  2021     USA                                        Foot bitten
# 361  2020     USA                               Minor injury to foot
# 363  2020     USA                      Minor lacerations to left leg
# ...

# %%
unique_injuries = recent_injuries['Injury'].unique()
unique_injuries
# Out:
# array(['Llacerations to face and chin', 'Ankle injured',
#        'Minor injury to foot', 'Foot bitten', 'Bite to right foot',
#        'Minor injuries to knee and calf of left leg                            PROVOKED INCIDENT                 ',
#        'Minor cuts to right foot and ankle', 'Leg bitten',
#        'Right calf bitten', 'Minor injury to right foot',
#        'Minor lacerations to left leg', 'Lacerations to foot ',
#        'Left foot bitten ',
#        'Left foot bitten when he jumped on the shark  PROVOKED INCIDENT',
#        'No injury, knocked from his board by the shark',
#        'Minor cuts when he jumped off his board and landed on the shark. PROVOKED INCIDENT',
#        'Hand and calf bitten when he jumped off surfboard and landed on the shark PROVOKED INCIDENT',
#        'Puncture marks to lower leg', 'Minor injuries to right foot',
#        'Minor cuts to right foot', 'Bite to left hand and wrist',
# ...

# %%
injury_counts = recent_injuries["Injury"].value_counts
injury_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 40                         Llacerations to face and chin
# 54                                         Ankle injured
# 159                                 Minor injury to foot
# 162                                          Foot bitten
# 197                                   Bite to right foot
# 198    Minor injuries to knee and calf of left leg   ...
# 242                   Minor cuts to right foot and ankle
# 256                                           Leg bitten
# 274                                    Right calf bitten
# 275                           Minor injury to right foot
# 287                                          Foot bitten
# 361                                 Minor injury to foot
# 363                        Minor lacerations to left leg
# 369                                 Lacerations to foot
# 377                                          Foot bitten
# 409                                    Left foot bitten
# ...

# %%
recent_injuries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 40 to 491
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      27 non-null     int32
#  1   Country   27 non-null     object
#  2   Injury    27 non-null     object
#  3   Location  27 non-null     object
# dtypes: int32(1), object(3)
# memory usage: 972.0+ bytes

# %%
location_counts = USA_data['Location'].value_counts()
location_counts
locations_counts_sum = sum(location_counts)
locations_counts_sum
# Out:
# 2475

# %%
recent_injuries_counts = recent_injuries['Injury'].value_counts()
ecent_injuries_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 recent_injuries_counts = recent_injuries['Injury'].value_counts()
# ----> 2 ecent_injuries_counts
#
# NameError: name 'ecent_injuries_counts' is not defined

# %%
recent_injuries_counts.describe()
# Out:
# count    23.000000
# mean      1.173913
# std       0.576208
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000
# Name: count, dtype: float64
